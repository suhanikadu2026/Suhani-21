# %%
x = 4;
print(type(x))
# Out:
# <class 'int'>

# %%
fruits = ["Apple", "Banana", "mango", "Orange"]
print("Original fruits : ",fruits)
fruits.append("Grapes")
print("After append: ",fruits)
fruits.remove("Apple")
print("after removing: ",fruits)
print("fruits first: ",fruits[0])
# Out:
# Original fruits :  ['Apple', 'Banana', 'mango', 'Orange']
# After append:  ['Apple', 'Banana', 'mango', 'Orange', 'Grapes']
# after removing:  ['Banana', 'mango', 'Orange', 'Grapes']
# fruits first:  Banana

# %%
tup = (1,2,3,4)
print(tup)
c = ("pink","blue","black")
print(c)
print("First colors: ",c[0])
print("Last colors : ",c[2])
print(len(tup))
print(len(c))
# Out:
# (1, 2, 3, 4)
# ('pink', 'blue', 'black')
# First colors:  pink
# Last colors :  black
# 4
# 3

# %%
numbers = {10,20,30,40,50}
print(numbers)
numbers.add(60)
print("After adding : ",numbers)

numbers.remove(40)
print("After removing: ",numbers)
print("Is 20 present?", 20 in numbers)
print("is 80 present: ",80 in  numbers)
# Out:
# {50, 20, 40, 10, 30}
# After adding :  {50, 20, 40, 10, 60, 30}
# After removing:  {50, 20, 10, 60, 30}
# Is 20 present? True
# is 80 present:  False

# %%
student = {
    "Name": "suhani",
    "Roll no" : 101,
    "Department" : "CSE"
}
print("Student details: ",student)
print("Name:",student["Name"])
student["semester"]=3
student["Department"]="CSE_AIML"
print("upadeted Student: ",student)
# Out:
# Student details:  {'Name': 'suhani', 'Roll no': 101, 'Department': 'CSE'}
# Name: suhani
# upadeted Student:  {'Name': 'suhani', 'Roll no': 101, 'Department': 'CSE_AIML', 'semester': 3}

# %%
a = 9;
print(a)
# Out:
# 9

# %%
num =int( input("Enter your mobile no: "))
print(num)
print(type(num))

# %%
list1 = [10,20,30,40,60]
print(list1)
set1={"banana","apple","you"}
print(set1)
tuple1 = (100,200,300,400)
print(tuple1)
employee = {
    "Name": "Janu",
    "Salary": 200000,
    "Department": "ETC",
    "Proffession": "Teacher"
}
print("Employee Detailed: ",employee)

# %%
a = float(input("Enter you percentage: "))
print(a)
print(type(a))

# %%
"""
you have to
learn codding from your
from youtube """
#print(A)

# %%
print("Anushka","Shagun","Holi")

# %%
print("Hello", end=" ")
print("World")

# %%
print("Shagun","Holi" ,sep="_")

# %%
a = 12
b = int(input("Enter your second :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        "))
print("Addition: ",a+b)
print("Subtraction: ",a-b)
print("Mul: ",a*b)
print("Division: ",a/b)
print("Quotient: ",a%b)

# %%
x = True
y = False
print("And logiacal op: ",x and y)
print("Logical or: ",x or y)
print("Logical not: ",not x)

# %%
a=345
b=566
if (a>b) :
  print(a)
else :
  print(b)

# %%
print("Hello this wolrd is very complicated")

# %%
a = 78
b = 79
print("Equal: ",a==b)
print(a>b)
print(b<a)
print(a!=b)

# %%
a

# %%
import keyword
keyword.kwlist

# %%
var = input("Enter your first string: ")
print(var)
print(type(var))
